# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# Load data 
df = pd.read_csv('../data/nigeria.csv') 

# Clean column names (removes any accidental spaces)
df.columns = [c.strip() for c in df.columns]

# Add Country column
df['Country'] = 'Nigeria'

# Convert YEAR and DOY to a proper datetime column
# %Y%j is the format for Year + Day of Year
df['Date'] = pd.to_datetime(df["YEAR"] * 1000 + df["DOY"], format="%Y%j")

# Extract Month for seasonal analysis
df['Month'] = df['Date'].dt.month

print("Success! Step 1 Complete: Data loaded and dates parsed.")
df.head()
# Out:
# Success! Step 1 Complete: Data loaded and dates parsed.
#    YEAR  DOY    T2M  T2M_MAX  T2M_MIN  T2M_RANGE  PRECTOTCORR   RH2M  WS2M  \
# 0  2015    1  25.23    29.25    22.06       7.19          0.0  68.26  1.73
# 1  2015    2  26.16    29.41    22.87       6.54          0.0  73.23  1.42
# 2  2015    3  25.66    29.02    22.63       6.39          0.0  78.71  1.69
# 3  2015    4  24.11    27.27    19.92       7.35          0.0  63.66  2.15
# 4  2015    5  23.40    27.28    18.18       9.10          0.0  59.45  1.88
#
#    WS2M_MAX      PS   QV2M  Country       Date  Month
# 0      2.61  100.86  13.36  Nigeria 2015-01-01      1
# 1      1.95  100.94  15.37  Nigeria 2015-01-02      1
# 2      2.33  101.06  15.98  Nigeria 2015-01-03      1
# 3      3.80  101.09  11.65  Nigeria 2015-01-04      1
# 4      3.48  101.03  10.40  Nigeria 2015-01-05      1

# %%
# 1. Replace NASA sentinel -999 with NaN (Not a Number)
df.replace(-999, np.nan, inplace=True)

# 2. Check for duplicate rows
duplicates = df.duplicated().sum()
print(f"Duplicate rows found: {duplicates}")
df.drop_duplicates(inplace=True)

# 3. Missing Value Report
null_report = df.isna().sum()
null_pct = (null_report / len(df)) * 100
print("\nPercentage of missing values per column:")
print(null_pct[null_pct > 0])

# 4. Cleaning: Fill missing values using Forward Fill
# This takes the value from the previous day and fills the gap
df.ffill(inplace=True)

print("\nCleaning Complete!")
# Out:
# Duplicate rows found: 0
#
# Percentage of missing values per column:
# Series([], dtype: float64)
#
# Cleaning Complete!

# %%
# Select the columns the task asked for
cols_to_check = ['T2M', 'T2M_MAX', 'T2M_MIN', 'PRECTOTCORR', 'RH2M', 'WS2M']

# Calculate Z-scores (how many standard deviations away from the mean)
z_scores = np.abs(stats.zscore(df[cols_to_check]))

# Identify rows where any column has a Z-score > 3
outliers = (z_scores > 3).any(axis=1)
print(f"Total rows with extreme outliers: {outliers.sum()}")

# Export the cleaned data to your data folder (KPI Requirement)
df.to_csv('../data/nigeria_clean.csv', index=False)
# Out:
# Total rows with extreme outliers: 219

# %% [markdown]
# Detected 219 rows with extreme outliers (∣Z∣>3). I have decided to retain these rows because, in climate analysis, these points often represent significant extreme weather events which are critical for policy and adaptation planning.

# %%
# Aggregate daily data to monthly: 'ME' stands for Month End
# T2M is averaged, PRECTOTCORR (Rain) is summed
monthly_df = df.resample('ME', on='Date').agg({'T2M':'mean', 'PRECTOTCORR':'sum'})

# 1. Plot Monthly Temperature
plt.figure(figsize=(14, 5))
plt.plot(monthly_df.index, monthly_df['T2M'], color='red', marker='o')
plt.title('Monthly Average Temperature - Nigeria (2015-2026)')
plt.ylabel('Temp (°C)')
plt.grid(True, alpha=0.3)
plt.show()

# 2. Plot Monthly Precipitation (Rainfall)
plt.figure(figsize=(14, 5))
plt.bar(monthly_df.index, monthly_df['PRECTOTCORR'], color='blue', width=20)
plt.title('Monthly Total Precipitation - Nigeria')
plt.ylabel('Rainfall (mm)')
plt.show()

# %%
# Select the numeric climate columns
cols_to_check = ['T2M', 'T2M_MAX', 'T2M_MIN', 'PRECTOTCORR', 'RH2M', 'WS2M']

# 1. Heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(df[cols_to_check].corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap of Climate Variables - Nigeria')
plt.show()

# 2. Scatter Plot: Temperature vs Humidity
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x='T2M', y='RH2M', alpha=0.4, color='green')
plt.title('Relationship: Temperature vs. Relative Humidity')
plt.show()

# %%
# 1. Histogram of Rainfall (Log scale)
plt.figure(figsize=(8, 5))
sns.histplot(df['PRECTOTCORR'], bins=30, kde=True, log_scale=(False, True))
plt.title('Distribution of Daily Precipitation (Log Scale)')
plt.show()

# 2. Bubble Chart: Temp vs Humidity (Size = Rainfall)
sample_df = df.sample(500, random_state=42)
plt.figure(figsize=(10, 7))
scatter = plt.scatter(sample_df['T2M'], sample_df['RH2M'], 
                      s=sample_df['PRECTOTCORR']*15, alpha=0.5, 
                      c=sample_df['PRECTOTCORR'], cmap='Blues')
plt.title('Bubble Chart: Temp vs Humidity (Bubble Size = Rainfall)')
plt.xlabel('Temperature (°C)')
plt.ylabel('Humidity (%)')
plt.colorbar(scatter, label='Precipitation (mm)')
plt.show()

# Export cleaned data (Important KPI)
df.to_csv('../data/nigeria_clean.csv', index=False)
print("Cleaned data exported to data/nigeria_clean.csv")
# Out:
# Cleaned data exported to data/nigeria_clean.csv

# %% [markdown]
# # Nigeria Climate Analysis: Negotiation-Grade Insights
#
# ### 1. What is changing? (Trend)
# Nigeria displays a very strong, high-amplitude seasonal rainfall cycle. While temperatures are stable (25°C - 29°C), the precipitation data shows massive volatility, with peak rainy seasons in 2019 and 2022 reaching nearly double the volume of drier years.
#
# ### 2. What did it cause? (Impact)
# The 219 outliers represent extreme tropical weather events. The bubble chart shows that heavy rainfall (>60mm/day) is "unlocked" only when humidity exceeds 85%. This indicates that Nigeria's flood risk is not just about rain, but about sustained high-atmospheric moisture which leads to the intense outlier events identified.
#
# ### 3. What does it demand? (Policy)
# Nigeria’s data demands a shift from "drought management" to **"flood-hazard mitigation."** We demand COP32 support for **Green Infrastructure** (wetland restoration) to absorb the massive precipitation peaks seen in the 2020-2022 period. Additionally, the high number of outliers justifies a demand for **sovereign climate risk insurance** to protect the economy from these frequent extreme weather shocks.
